# %%
from datasets import load_dataset, concatenate_datasets

# 데이터셋 로드
test_kiqu = load_dataset("maywell/test_kiqu")
ko_wikidata_QA = load_dataset("maywell/ko_wikidata_QA")

# 전체 구조 확인
print(test_kiqu)
print(ko_wikidata_QA)

data = concatenate_datasets([test_kiqu['train'], ko_wikidata_QA['train']])
print(data)
# Out:
# README.md:   0%|          | 0.00/316 [00:00<?, ?B/s]
# train-00000-of-00001.parquet:   0%|          | 0.00/2.81M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/3000 [00:00<?, ? examples/s]
# README.md:   0%|          | 0.00/770 [00:00<?, ?B/s]
# train.csv:   0%|          | 0.00/144M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/137505 [00:00<?, ? examples/s]
# DatasetDict({
#     train: Dataset({
#         features: ['instruction', 'output'],
#         num_rows: 3000
#     })
# })
# DatasetDict({
#     train: Dataset({
#         features: ['instruction', 'output'],
#         num_rows: 137505
#     })
# })
# Dataset({
#     features: ['instruction', 'output'],
#     num_rows: 140505
# })

# %%
import pandas as pd
df = pd.DataFrame(data)
df.head()
# Out:
#                           instruction  \
# 0                       카리브 미술이 무엇이야?
# 1         상업용 부동산 시장이 팬데믹으로 어떻게 변화했어?
# 2  부상이나 질병에 대처하기 위해 인체가 필요로 하는 것이 뭐야?
# 3              비숑 프리제는 어떤 특징을 가지고 있어?
# 4              긴 운전 여행이 처음 시작된 건 언제야?
#
#                                               output
# 0  카리브 미술이라는 용어는 카리브해 지역에서 발달한 미술을 가리키는 말이에요. 카리브...
# 1  팬데믹으로 인해 상업용 부동산 시장에도 큰 변화가 일어났어요. 특히 사무실, 쇼핑몰...
# 2  인체가 부상이나 질병에 대처하기 위해 필요로 하는 것은 여러 가지가 있어요. 가장 ...
# 3  비숑 프리제(Bichon Frise)는 작고 귀여운 품종의 개로, 특징적인 털과 친...
# 4  긴 운전 여행이 시작된 시기는 자동차의 발명과 함께 점점 더 인기를 얻기 시작한 2...

# %%
# 새로운 데이터프레임 형식으로 변환
converted_data = {
    "id": [f"index-{i}" for i in df.index],
    "paragraph": df["output"],
    "question": df["instruction"],
    "choices": [[] for _ in df.index],  # 빈 리스트로 초기화
    "answer": [None for _ in df.index],  # None으로 초기화
    "question_plus": ["N/A" for _ in df.index]  # "N/A"로 초기화
}


converted_df = pd.DataFrame(converted_data)
converted_df.head()
# Out:
#         id                                          paragraph  \
# 0  index-0  카리브 미술이라는 용어는 카리브해 지역에서 발달한 미술을 가리키는 말이에요. 카리브...
# 1  index-1  팬데믹으로 인해 상업용 부동산 시장에도 큰 변화가 일어났어요. 특히 사무실, 쇼핑몰...
# 2  index-2  인체가 부상이나 질병에 대처하기 위해 필요로 하는 것은 여러 가지가 있어요. 가장 ...
# 3  index-3  비숑 프리제(Bichon Frise)는 작고 귀여운 품종의 개로, 특징적인 털과 친...
# 4  index-4  긴 운전 여행이 시작된 시기는 자동차의 발명과 함께 점점 더 인기를 얻기 시작한 2...
#
#                              question choices answer question_plus
# 0                       카리브 미술이 무엇이야?      []   None           N/A
# 1         상업용 부동산 시장이 팬데믹으로 어떻게 변화했어?      []   None           N/A
# 2  부상이나 질병에 대처하기 위해 인체가 필요로 하는 것이 뭐야?      []   None           N/A
# 3              비숑 프리제는 어떤 특징을 가지고 있어?      []   None           N/A
# 4              긴 운전 여행이 처음 시작된 건 언제야?      []   None           N/A

# %%
import pandas as pd
import google.generativeai as genai
import time
import random
 
GOOGLE_API_KEY="AIzaSyAMvb1Fbq6R0u4cQYmj3V7vV2WwXxx0vj8"
 
genai.configure(api_key=GOOGLE_API_KEY)
 
model = genai.GenerativeModel('gemini-1.5-flash')

# 질문 변환 함수
def transform_question_with_genai(question):
    prompt = (
        f"아래 문장을 참고하여 질문을 '~에 대한 설명으로 옳지 않은 것은?' 형식으로 바꿔줘:\n\n"
        f"질문: {question}\n\n"
        "새로운 질문:"
    )
    
    retries = 3  # 재시도 횟수
    for attempt in range(retries):
        try:
            # API 호출
            response = model.generate_content(prompt)
            
            # 응답 처리
            if response and hasattr(response, "text"):
                return response.text.strip()
        except Exception as e:
            if "429" in str(e) or "TooManyRequests" in str(e):
                print(f"Rate limit exceeded. Retrying... ({attempt + 1}/{retries})")
                time.sleep(3 + random.uniform(0, 2))  # 고정 + 랜덤 지연
            elif "Connection" in str(e):
                print(f"Connection error. Retrying... ({attempt + 1}/{retries})")
                time.sleep(5)
            else:
                print(f"Unhandled error: {e}")
                break
    
    return "변환 실패"

# 반복문을 사용해 질문 변환
new_questions = []
for index, row in converted_df.iterrows():
    print(f"Processing row {index + 1}/{len(converted_df)}: {row['question']}")
    new_question = transform_question_with_genai(row['question'])
    new_questions.append(new_question)
    time.sleep(3)  # 요청 간 고정 지연 추가

# 결과 저장
converted_df["new_question"] = new_questions

# 결과 확인
print(converted_df.head())
converted_df.to_csv("transformed_questions.csv", index=False, encoding='utf-8-sig')
print("결과가 'transformed_questions.csv'로 저장되었습니다.")
# Out:
# Processing row 1/140505: 카리브 미술이 무엇이야?
# Processing row 2/140505: 상업용 부동산 시장이 팬데믹으로 어떻게 변화했어?
# Processing row 3/140505: 부상이나 질병에 대처하기 위해 인체가 필요로 하는 것이 뭐야?
# Processing row 4/140505: 비숑 프리제는 어떤 특징을 가지고 있어?
# Processing row 5/140505: 긴 운전 여행이 처음 시작된 건 언제야?
# Processing row 6/140505: 코로나19를 이기기 위해 혁신이 왜 중요해?
# Processing row 7/140505: 신흥 시장에서 공정 거래가 어렵다고 생각하는 이유는 뭐야?
# Processing row 8/140505: 음악이 문화 간 교류를 촉진하는 데 어떻게 도움이 돼?
# Processing row 9/140505: 경찰이 검색 영장 없이 개인의 재산을 수색할 수 있어야 한다는 주장에 대해 어떻게 생각해?
# Processing row 10/140505: 사진적 기억력이란 무엇이야?
# Processing row 11/140505: 잠을 자지 않고도 휴식을 취할 수 있는 방법이 있어?
# Processing row 12/140505: 산악 전쟁에서 방어자에게 주는 장점이 뭐야?
# Processing row 13/140505: 과학이 추상적인 이유는 뭐야?
# Processing row 14/140505: 코퀴가 그들을 파괴할 수 있어?
# Processing row 15/140505: 레eway가 뭐야?
# Processing row 16/140505: 진실이 봄처럼 돌아오는 건 어떻게 가능해?
# Processing row 17/140505: 오스트레일리아에서 럭비 리그가 시작된 건 언제야?
# Processing row 18/140505: Calabasas High School 축구 팀이 최근 어려움을 겪었다고 했는데, 구체적으로 어떤 어려움을 겪었어?
# Processing row 19/140505: 소녀와의 포화친밀이 청소년에게 부정적인 영향을 미칠 수 있어?
# Processing row 20/140505: 진정한 성공을 이루는 데 있어서 열정과 헌신이 왜 중요해?
# Processing row 21/140505: 북극곰이 추운 환경에 적응하기 위해 어떤 특성을 가지고 있어?
# Processing row 22/140505: 캘리포늄은 어떻게 만들어졌어?
# Processing row 23/140505: 전자 화폐가 경제에 긍정적인 충격을 줄 수 있어?
# Processing row 24/140505: 예술과 음악이 혼돈과 상업화에 침몰함에 따라 실질적인 의미가 희석되고 있어?
# Processing row 25/140505: ATV가 뭐야?
# Processing row 26/140505: 망상과 꿈의 차이점이 뭐야?
# Processing row 27/140505: 소셜 미디어가 학생들에게 미치는 긍정적인 영향은 뭐야?
# Processing row 28/140505: 도그 트릭이 인간-동물 관계에 어떤 긍정적인 영향을 미쳐?
# Processing row 29/140505: 일과 열정이 뭐야?
# Processing row 30/140505: 성적 외상을 당한 사람들이 자신이 성적 보살핌을 받고 싶어하는 의욕을 가질 수 있어?
# Processing row 31/140505: 아프리카 관광업이 처음 시작된 건 언제야?
# Processing row 32/140505: 무서움과 직면하는 것이 삶의 진정한 의미라고 생각해?
# Processing row 33/140505: 1976년 필리핀 국민투표가 어떤 상황에서 치러졌어?
# Processing row 34/140505: 개인의 신념이 사회의 요구와 충돌할 때, 어떻게 해야 해?
# Processing row 35/140505: 영혼이 존재한다고 가정하면 영혼이 고통을 받을 수 있어?
# Processing row 36/140505: 고무 산업에서 접착이 왜 중요해?
# Processing row 37/140505: 대중의 이익을 위해 개인의 자유를 제한하는 것이 왜 필요해?
# Processing row 38/140505: 자연과 연결된다는 건 어떤 의미야?
# Processing row 39/140505: 여성의 아름다움이 생득적 특성에 더 의존한다고 생각하는 이유는 뭐야?
# Rate limit exceeded. Retrying... (1/3)
# Rate limit exceeded. Retrying... (2/3)
# Processing row 40/140505: 누군가가 우리 상황에 있었던 적이 없다고 말할 때 얼마나 신뢰할 수 있어?
# Processing row 41/140505: 다와는 무엇이야?
# Processing row 42/140505: 기업이 브랜드화 및 마케팅 캠페인에서 사용할 수 있는 추가 키워드의 혁신적인 개념에는 무엇이 있어?
# Processing row 43/140505: 아랍의 북아프리카 정복이 일어난 시기는 언제야?
# Processing row 44/140505: 소닉 스크류드라이버가 시간 여행을 가능하게 하는 원리는 뭐야?
# Processing row 45/140505: 생물의 계통이 무작위적으로 결정된다는 건 어떤 의미야?
# Processing row 46/140505: 음악 협업이란 무엇이야?
# Processing row 47/140505: 예정된 목적론이 우리에게 더 큰 책임감을 부여한다고 생각해?
# Processing row 48/140505: 중세 의류가 오늘날의 패션에 미치는 영향이 왜 큰 거야?
# Processing row 49/140505: 영혼이 죽음 이후에도 계속 존재한다고 생각해?
# Processing row 50/140505: 드워프 은하가 왜 중요해?
# Processing row 51/140505: Taoyuan에는 어떤 언어들이 사용되고 있어?
# Processing row 52/140505: 급조기 교육이 뭐야?
# Processing row 53/140505: 새 수학 교육과정이 학생들의 수학적 능력 향상에 도움이 될까?
# Processing row 54/140505: 자만이 긍정적인 결과를 가져올 수 있어?
# Rate limit exceeded. Retrying... (1/3)
# Processing row 55/140505: 아프리카에서 성공적인 민주주의를 형성하는 것이 불가능하다고 생각하는 이유가 뭐야?
# Processing row 56/140505: 집단 폭력에 대한 총기 규제가 개인 폭력에도 유사하게 적용될 수 있어?
# Processing row 57/140505: 기억 상실증이 정신 건강에 어떤 영향을 미쳐?
# Processing row 58/140505: 아르메니아 디아스포라가 뭐야?
# Processing row 59/140505: 전통적인 서정시의 주제가 뭐야?
# Processing row 60/140505: 보험이 왜 필요한 악이야?
# Processing row 61/140505: 다리의 역사는 언제부터야?
# Processing row 62/140505: 죄책감이 뭐야?
# Processing row 63/140505: 플라톤의 동굴 비유가 마녀의 존재를 증명하는 데 어떻게 도움이 돼?
# Processing row 64/140505: 화장품 산업의 역사는 언제부터 시작됐어?
# Processing row 65/140505: 코데펜던트와 나르시시스트 사이의 관계에서 코데펜던트가 나르시시스트의 강한 성격에 끌린다는 건 어떤 의미야?
# Processing row 66/140505: 불멸의 생명체가 가능하다고 생각해?
# Processing row 67/140505: 뉴스를 너무 많이 보는 것이 수동적인 삶으로 이어질 수 있다고 생각하는 이유가 뭐야?
# Processing row 68/140505: 창의성을 방해하는 가장 일반적인 장애물은 뭐야?
# Processing row 69/140505: 프로 축구선수가 되기 위해 어린 시절에 어떤 교육을 받아야 해?
# Rate limit exceeded. Retrying... (1/3)
# Processing row 70/140505: 기업이 인공지능에 대한 투자를 확대해야 하는 이유가 뭐야?
# Processing row 71/140505: 국가의 주권이 폭력적 국가의 잔재라고 생각해?
# Processing row 72/140505: TV 프로그램이 우리의 생각과 행동에 어떻게 영향을 미쳐?
# Processing row 73/140505: 종교가 평화를 창조하는 데 어떻게 도움이 돼?
# Processing row 74/140505: 농민 개혁이 정치적 노력과 효과 사이의 균형을 찾는 과제라고 생각하는 이유가 뭐야?
# Processing row 75/140505: 플러드 조지 정보 분석 플랫폼이 뭐야?
# Processing row 76/140505: 견과류가 심장 건강에 어떻게 도움이 돼?
# Processing row 77/140505: 21세기 미디어 산업에서 성공을 위해 포용성이 왜 중요해?
# Processing row 78/140505: 신앙을 공유하는 두 사람이 같은 지역에서 살아가면 어떤 이점이 있어?
# Processing row 79/140505: 종말론 이론이 뭐야?
# Processing row 80/140505: 탐정이 정의를 실현하는 데 어떻게 도움이 돼?
# Processing row 81/140505: 공공 인물과 브랜딩을 구축하는 법에 대해 더 자세히 알려줄 수 있어?
# Processing row 82/140505: 모성이 여성의 정신 건강에 어떤 긍정적인 영향을 줄 수 있어?
# Processing row 83/140505: 국립 등록 유산지가 뭐야?
# Processing row 84/140505: 인간이 완전한 행복을 경험할 수 있어?
# Processing row 85/140505: 철도가 항공기보다 느리지만 왜 여전히 더 안전하고 정확하다고 생각해?
# Processing row 86/140505: 차별화가 경제에서 어떤 문제를 일으킬 수 있어?
# Processing row 87/140505: 자연 재해의 피해로부터 완전히 회복하는 것이 불가능하다고 생각해?
# Processing row 88/140505: 시리아 내전이 시작된 건 언제야?
# Processing row 89/140505: 인공 지능에 과도하게 의존하는 것을 어떻게 막을 수 있어?
# Processing row 90/140505: 경기부양 정책이 무엇이야?
# Processing row 91/140505: 자연의 아름다움을 예술, 문학, 음악을 통해 경험할 수 있어?
# Processing row 92/140505: John Batmanson의 작품이 전통적인 중세 신학과 인문주의적 신학 사이에서 어떤 위치에 있어?
# Processing row 93/140505: 종교의 기원은 어떻게 되는 거야?
# Processing row 94/140505: 연령이나 기타 개인적 특성이 창의적 표현에 영향을 미칠 수 있어?
# Processing row 95/140505: 전기자동차가 내연기관 자동차보다 왜 환경 친화적이야?
# Processing row 96/140505: 카이엔이 뭐야?
# Processing row 97/140505: 정부가 의료 서비스 이용에 대해 어떤 역할을 해야 해?
# Processing row 98/140505: H&R Block이 기술에 많은 투자를 하는 이유가 뭐야?
# Processing row 99/140505: 인공지능이 메이크업 추천에 어떻게 도움이 돼?
# Processing row 100/140505: 화학 에너지가 뭐야?
# Processing row 101/140505: 과학과 신앙이 뭐야?
# Processing row 102/140505: 도로쓰레기가 환경에 어떤 영향을 미쳐?
# Processing row 103/140505: 유전자 변형 식품이 환경에 어떤 긍정적인 영향을 미칠 수 있어?
# Processing row 104/140505: 컴퓨터 모니터 기술이 어떻게 발전해 왔어?
# Processing row 105/140505: 사회적 책임이 뭐야?
# Processing row 106/140505: 사냥-채집 사회에서 식물을 채집하는 방법은 어떻게 하는 거야?
# Processing row 107/140505: 미디어가 폭력적인 콘텐츠를 보도하는 것이 사람들에게 어떤 영향을 줄 수 있어?
# Processing row 108/140505: 세상이 탐험하기 어려워진 이유가 뭐야?
# Processing row 109/140505: 사법 제도가 사회에 어떤 역할을 해?
# Processing row 110/140505: 스포츠와 정치의 관계가 어떻게 시작됐어?
# Processing row 111/140505: 전쟁이 항상 불필요한 야만적인 행위야?
# Processing row 112/140505: 어린이들이 코로나19에 대해 어떻게 이해해야 해?
# Processing row 113/140505: 상업 은행 규제가 경제 회복에 어떻게 도움이 되는 거야?
# Processing row 114/140505: 개인의 가치는 어떻게 정의해야 해?
# Processing row 115/140505: 신이 기적을 무차별적으로 행하는 이유가 뭐야?
# Processing row 116/140505: 금성의 평균 기온은 얼마나 돼?
# Processing row 117/140505: 인간에게 자유 의지가 있어야 하는 이유가 뭐야?
# Processing row 118/140505: 스코틀랜드가 영국에 머물러 있는 게 스코틀랜드인에게 어떤 이점이 있어?
# Processing row 119/140505: 가족 구성원간의 건강한 관계를 유지하는 것이 왜 중요해?
# Processing row 120/140505: 주니어 유로비전 송 콘테스트에서 심사 위원의 평가와 대중 투표를 모두 통해 우승자를 선정하는 것이 왜 공정하다고 생각해?
# Processing row 121/140505: 어린 시절에 부모님으로부터 긍정적인 경험과 말씀을 들었을 때 어떤 긍정적인 영향을 받게 되는 거야?
# Processing row 122/140505: 동물이 인간보다 더 충실하고 신뢰할 수 있는 친구라고 생각해?
# Processing row 123/140505: 하느님이 사랑이시다고 말하는 이유는 뭐야?
# Processing row 124/140505: 유명 인사의 비밀 도촬이 뭐야?
# Processing row 125/140505: 입학자들이 원하는 캠퍼스 분위기는 뭐야?
# Processing row 126/140505: 의료 분야에서 X선 차폐 유리가 왜 중요해?
# Processing row 127/140505: 로스앤젤레스가 영화 산업의 중심지가 될 수 있었던 주된 이유는 뭐야?
# Processing row 128/140505: 아이디어와 고통이 상보적인 관계에 있다는 주장은 어떻게 뒷받침돼?
# Processing row 129/140505: 연약해 보이는 사람들을 돌보는 것이 도와주는 사람에게 어떤 긍정적인 감정을 줄 수 있어?
# Processing row 130/140505: 반조가 다양한 장르에 걸쳐 다양한 음악을 만드는 데 사용될 수 있어?
# Processing row 131/140505: 자율 무기를 사용하는 것이 도덕적으로 잘못된 이유는 뭐야?
# Processing row 132/140505: 사용자 경험이란 무엇이야?
# Processing row 133/140505: 테일러 스위프트가 노래에 담는 주요 주제는 뭐야?
# Processing row 134/140505: 세계화가 바다 산업에 어떤 기회를 가져왔어?
# Processing row 135/140505: 레이저가 콘서트에서 어떻게 사용돼?
# Processing row 136/140505: 혼합 가족이 뭐야?
# Processing row 137/140505: 대기가 왜 중요해?
# Processing row 138/140505: AI가 회계 분야에 미치는 영향은 어떤 거야?
# Processing row 139/140505: 자전거 여행이 왜 영적 성장에 도움이 돼?
# Processing row 140/140505: 심리학자가 연구를 수행할 때 윤리적 의무가 뭐야?
# Processing row 141/140505: 슬라임 몰드가 의식을 가지고 있다고 생각해?
# Processing row 142/140505: 희소 금속이 뭐야?
# Processing row 143/140505: 스포츠에서 경쟁과 협동이 상호 의존적이라고 생각해?
# Processing row 144/140505: 탄소 섬유 복합재가 무엇이야?
# Processing row 145/140505: 밀린크 마을에서 크리스마스 장식을 전기에서 태양 전지로 교체하는 것이 경제적으로 어떻게 이득이 되는 거야?
# Processing row 146/140505: 기술 발전이 인간의 생활에 어떻게 긍정적인 영향을 미쳤어?
# Processing row 147/140505: 초인적인 능력을 가진 사람이 사회를 위해 봉사하고 세상을 더 나은 곳으로 만들어야 한다고 생각해?
# Rate limit exceeded. Retrying... (1/3)
# Processing row 148/140505: 영화 "대부"의 은유적 의미를 해석하는 것이 왜 중요해?
# Rate limit exceeded. Retrying... (1/3)
# Processing row 149/140505: 새장 청소가 왜 중요해?
# Rate limit exceeded. Retrying... (1/3)
# Rate limit exceeded. Retrying... (2/3)
# Rate limit exceeded. Retrying... (3/3)
# Processing row 150/140505: GMO 채택이 경제적 비용을 넘어서는 경우에도 공익을 위해 채택해야 한다고 생각해?
# Processing row 151/140505: Galapagos 군도가 처음 발견된 건 언제야?
# Rate limit exceeded. Retrying... (1/3)
# Rate limit exceeded. Retrying... (2/3)
# Rate limit exceeded. Retrying... (3/3)
# Processing row 152/140505: Supreme Soul이 뭐야?
# Processing row 153/140505: 스포츠가 개인에게 부정적인 영향을 미칠 수 있어?
# Rate limit exceeded. Retrying... (1/3)
# Rate limit exceeded. Retrying... (2/3)
# Rate limit exceeded. Retrying... (3/3)
# Processing row 154/140505: 팀과 선수의 개인적 관계와 인내심이 스포츠에서 왜 중요해?
# Rate limit exceeded. Retrying... (1/3)
# Rate limit exceeded. Retrying... (2/3)
# Rate limit exceeded. Retrying... (3/3)
# Processing row 155/140505: 웹을 탐험할 때 정보 과부하라는 문제가 뭐야?
# Rate limit exceeded. Retrying... (1/3)
# Rate limit exceeded. Retrying... (2/3)
# Rate limit exceeded. Retrying... (3/3)
# Processing row 156/140505: 기계화 전쟁의 발전이 기병대의 시대의 종식을 의미하는 거야?
# Rate limit exceeded. Retrying... (1/3)
# Rate limit exceeded. Retrying... (2/3)
# Rate limit exceeded. Retrying... (3/3)
# Processing row 157/140505: 예술가들이 환경 문제에 대해 작품을 만드는 이유가 뭐야?
# Rate limit exceeded. Retrying... (1/3)
# Rate limit exceeded. Retrying... (2/3)
# Rate limit exceeded. Retrying... (3/3)
# Processing row 158/140505: 광산세가 왜 부과돼?
# Rate limit exceeded. Retrying... (1/3)
# Rate limit exceeded. Retrying... (2/3)
# Rate limit exceeded. Retrying... (3/3)
# Processing row 159/140505: 존재가 비존재로 진화하면서 도덕 원칙이 발생한다는 주장이 맞는 거야?
# Rate limit exceeded. Retrying... (1/3)
# Rate limit exceeded. Retrying... (2/3)
# Rate limit exceeded. Retrying... (3/3)
# Processing row 160/140505: 트라우마가 기억에 어떤 영향을 미쳐?
# Rate limit exceeded. Retrying... (1/3)
# Rate limit exceeded. Retrying... (2/3)
# Rate limit exceeded. Retrying... (3/3)
# Processing row 161/140505: 저축을 시작하기 위해 먼저 해야 할 일이 뭐야?
# Rate limit exceeded. Retrying... (1/3)
# Rate limit exceeded. Retrying... (2/3)
# Rate limit exceeded. Retrying... (3/3)
# Processing row 162/140505: 안전에 대한 갈구가 도덕적 공포를 키우는 데 어떤 역할을 하는 거야?
# Rate limit exceeded. Retrying... (1/3)
# Rate limit exceeded. Retrying... (2/3)
# Rate limit exceeded. Retrying... (3/3)
# Processing row 163/140505: BMW M57 엔진이 뭐야?
# Rate limit exceeded. Retrying... (1/3)
# Rate limit exceeded. Retrying... (2/3)
# Rate limit exceeded. Retrying... (3/3)
# Processing row 164/140505: 동물의 권리를 지지하는 주장 중에 하나는 무엇이야?
# Rate limit exceeded. Retrying... (1/3)
# Rate limit exceeded. Retrying... (2/3)
# Rate limit exceeded. Retrying... (3/3)
# Processing row 165/140505: 재즈가 인종적 조화에 어떻게 도움이 돼?
# Rate limit exceeded. Retrying... (1/3)
# Rate limit exceeded. Retrying... (2/3)
# Rate limit exceeded. Retrying... (3/3)
# Processing row 166/140505: 미네랄 퇴적물이 인체에 미치는 건 뭐야?
# Rate limit exceeded. Retrying... (1/3)
# Rate limit exceeded. Retrying... (2/3)
# Rate limit exceeded. Retrying... (3/3)
# Processing row 167/140505: Christopher Rawsthorne은 언제 태어났어?
# Rate limit exceeded. Retrying... (1/3)
# ---------------------------------------------------------------------------
# ResourceExhausted                         Traceback (most recent call last)
# Cell In[6], line 24, in transform_question_with_genai(question)
#      22 try:
#      23     # API 호출
# ---> 24     response = model.generate_content(prompt)
#      26     # 응답 처리
#
# File /opt/conda/lib/python3.10/site-packages/google/generativeai/generative_models.py:331, in GenerativeModel.generate_content(self, contents, generation_config, safety_settings, stream, tools, tool_config, request_options)
#     330 else:
# --> 331     response = self._client.generate_content(
#     332         request,
#     333         **request_options,
#     334     )
#     335     return generation_types.GenerateContentResponse.from_response(response)
#
# File /opt/conda/lib/python3.10/site-packages/google/ai/generativelanguage_v1beta/services/generative_service/client.py:830, in GenerativeServiceClient.generate_content(self, request, model, contents, retry, timeout, metadata)
#     829 # Send the request.
# --> 830 response = rpc(
#     831     request,
#     832     retry=retry,
#     833     timeout=timeout,
#     834     metadata=metadata,
#     835 )
#     837 # Done; return the response.
#
# File /opt/conda/lib/python3.10/site-packages/google/api_core/gapic_v1/method.py:131, in _GapicCallable.__call__(self, timeout, retry, compression, *args, **kwargs)
#     129     kwargs["compression"] = compression
# --> 131 return wrapped_func(*args, **kwargs)
#
# File /opt/conda/lib/python3.10/site-packages/google/api_core/retry/retry_unary.py:293, in Retry.__call__.<locals>.retry_wrapped_func(*args, **kwargs)
#     290 sleep_generator = exponential_sleep_generator(
#     291     self._initial, self._maximum, multiplier=self._multiplier
#     292 )
# --> 293 return retry_target(
#     294     target,
#     295     self._predicate,
#     296     sleep_generator,
#     297     timeout=self._timeout,
#     298     on_error=on_error,
#     299 )
#
# File /opt/conda/lib/python3.10/site-packages/google/api_core/retry/retry_unary.py:153, in retry_target(target, predicate, sleep_generator, timeout, on_error, exception_factory, **kwargs)
#     151 except Exception as exc:
#     152     # defer to shared logic for handling errors
# --> 153     _retry_error_helper(
#     154         exc,
#     155         deadline,
#     156         sleep,
#     157         error_list,
#     158         predicate,
#     159         on_error,
#     160         exception_factory,
#     161         timeout,
#     162     )
#     163     # if exception not raised, sleep before next attempt
#
# File /opt/conda/lib/python3.10/site-packages/google/api_core/retry/retry_base.py:212, in _retry_error_helper(exc, deadline, next_sleep, error_list, predicate_fn, on_error_fn, exc_factory_fn, original_timeout)
#     207     final_exc, source_exc = exc_factory_fn(
#     208         error_list,
#     209         RetryFailureReason.NON_RETRYABLE_ERROR,
#     210         original_timeout,
#     211     )
# --> 212     raise final_exc from source_exc
#     213 if on_error_fn is not None:
#
# File /opt/conda/lib/python3.10/site-packages/google/api_core/retry/retry_unary.py:144, in retry_target(target, predicate, sleep_generator, timeout, on_error, exception_factory, **kwargs)
#     143 try:
# --> 144     result = target()
#     145     if inspect.isawaitable(result):
#
# File /opt/conda/lib/python3.10/site-packages/google/api_core/timeout.py:120, in TimeToDeadlineTimeout.__call__.<locals>.func_with_timeout(*args, **kwargs)
#     118     kwargs["timeout"] = max(0, self._timeout - time_since_first_attempt)
# --> 120 return func(*args, **kwargs)
#
# File /opt/conda/lib/python3.10/site-packages/google/api_core/grpc_helpers.py:78, in _wrap_unary_errors.<locals>.error_remapped_callable(*args, **kwargs)
#      77 except grpc.RpcError as exc:
# ---> 78     raise exceptions.from_grpc_error(exc) from exc
#
# ResourceExhausted: 429 Resource has been exhausted (e.g. check quota).
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 46
#      44 for index, row in converted_df.iterrows():
#      45     print(f"Processing row {index + 1}/{len(converted_df)}: {row['question']}")
# ---> 46     new_question = transform_question_with_genai(row['question'])
#      47     new_questions.append(new_question)
#      48     time.sleep(3)  # 요청 간 고정 지연 추가
#
# Cell In[6], line 32, in transform_question_with_genai(question)
#      30 if "429" in str(e) or "TooManyRequests" in str(e):
#      31     print(f"Rate limit exceeded. Retrying... ({attempt + 1}/{retries})")
# ---> 32     time.sleep(3 + random.uniform(0, 2))  # 고정 + 랜덤 지연
#      33 elif "Connection" in str(e):
#      34     print(f"Connection error. Retrying... ({attempt + 1}/{retries})")
#
# KeyboardInterrupt:

# %%
converted_df.head()

# %%
# 보기 및 정답 생성 함수
def generate_choices_and_answer(row):
    prompt = (
        f"아래 질문을 참고하여 문맥 기반으로 올바른 보기를 4개와 틀린 보기를 1개 생성해줘.\n"
        f"보기는 ['보기 1', '보기 2', '보기 3', '보기 4', '보기 5'] 형식으로 출력해줘.\n"
        f"틀린 보기는 반드시 답이어야 하며, 보기 중 몇 번째인지도 알려줘.\n\n"
        f"문맥:\n{row['paragraph']}\n\n"
        f"질문:\n{row['new_question']}\n\n"
        "새로운 보기와 정답을 생성해줘."
    )
    
    retries = 3  # 재시도 횟수
    for attempt in range(retries):
        try:
            # API 호출
            response = model.generate_content(prompt)
            
            # 응답 처리
            if response and hasattr(response, "text"):
                result = response.text.strip()
                parts = result.split("\n")
                
                # 보기를 추출
                choices = parts[:5] if len(parts) >= 5 else ["보기 생성 실패"] * 5
                
                # 정답을 추출
                last_line = parts[-1]
                try:
                    # 정답 번호가 "보기 5"와 같은 형식으로 포함되어 있다고 가정
                    if "보기" in last_line:
                        answer = int(last_line.split("보기")[-1].strip()[0])  # '보기 X'에서 숫자만 추출
                    else:
                        raise ValueError(f"Unexpected answer format: {last_line}")
                except ValueError:
                    print(f"Invalid answer format in response: {last_line}")
                    answer = -1  # 기본값
                
                return choices, answer
        except Exception as e:
            if "429" in str(e) or "TooManyRequests" in str(e):
                print(f"Rate limit exceeded. Retrying... ({attempt + 1}/{retries})")
                time.sleep(3 + random.uniform(0, 2))  # 고정 + 랜덤 지연
            elif "Connection" in str(e):
                print(f"Connection error. Retrying... ({attempt + 1}/{retries})")
                time.sleep(5)
            else:
                print(f"Unhandled error: {e}")
                break
    
    return ["보기 생성 실패"] * 5, -1

# 반복문으로 보기를 생성
choices_list = []
answers = []

for index, row in converted_df.iterrows():
    print(f"Processing row {index + 1}/{len(converted_df)}: {row['new_question']}")
    choices, answer = generate_choices_and_answer(row)
    choices_list.append(choices)
    answers.append(answer)
    time.sleep(3)  # 요청 간 고정 지연 추가

# DataFrame에 결과 저장
converted_df["choices"] = choices_list
converted_df["answer"] = answers

# 결과 확인
print(converted_df.head())
converted_df.to_csv("final_questions_with_choices.csv", index=False, encoding="utf-8-sig")
print("결과가 'final_questions_with_choices.csv'로 저장되었습니다.")

# %%
converted_df.head()

# %%
# post-processing
# 1. answer = -1인 것은 지우기
# 2. choices -> 보기 1:, 보기 2: 보기 3: 등 이 텍스트 지우기
# 3. choices len()>=4 아니면 다 지우기
# 4. 기존 uestion 지우고, new_questions 칼럼을 question로 대체할 것 위치는 paragraph 옆으로	

# 1. answer = -1인 행 제거
filtered_df = converted_df[converted_df['answer'] != -1]

# 2. choices에서 "보기 1:", "보기 2:" 등의 텍스트 제거
filtered_df['choices'] = filtered_df['choices'].apply(
    lambda x: [choice.replace('보기 1:', '').replace('보기 2:', '').replace('보기 3:', '').replace('보기 4:', '').replace('보기 5:', '').strip() for choice in x]
)

# 3. choices의 길이가 4 미만인 행 제거
filtered_df = filtered_df[filtered_df['choices'].apply(len) >= 4]

# 4. 기존 question 컬럼 제거 후, new_question을 question으로 대체하고 위치 이동
filtered_df = filtered_df.drop(columns=['question'])  # 기존 question 삭제
filtered_df = filtered_df.rename(columns={'new_question': 'question'})  # new_question -> question

# question을 paragraph 옆으로 이동
columns = ['id', 'paragraph', 'question', 'choices', 'answer', 'question_plus']
filtered_df = filtered_df[columns]

# 결과 확인
print(filtered_df.head())

# (옵션) 결과 저장
filtered_df.to_csv("processed_dataset.csv", index=False, encoding="utf-8-sig")
